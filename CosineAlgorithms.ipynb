# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as ss
from scipy.linalg import *

# %%
# !pip install matchms
# Out:
# Requirement already satisfied: matchms in /usr/local/lib/python3.10/dist-packages (0.24.4)
# Requirement already satisfied: deprecated<2.0.0,>=1.2.14 in /usr/local/lib/python3.10/dist-packages (from matchms) (1.2.14)
# Requirement already satisfied: lxml<5.0.0,>=4.9.3 in /usr/local/lib/python3.10/dist-packages (from matchms) (4.9.4)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from matchms) (3.8.4)
# Requirement already satisfied: networkx<4.0,>=3.1 in /usr/local/lib/python3.10/dist-packages (from matchms) (3.3)
# Requirement already satisfied: numba<0.58.0,>=0.57.1 in /usr/local/lib/python3.10/dist-packages (from matchms) (0.57.1)
# Requirement already satisfied: numpy<1.25 in /usr/local/lib/python3.10/dist-packages (from matchms) (1.24.4)
# Requirement already satisfied: pandas<3.0.0,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from matchms) (2.0.3)
# Requirement already satisfied: pickydict<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from matchms) (0.4.0)
# Requirement already satisfied: pillow!=9.4.0 in /usr/local/lib/python3.10/dist-packages (from matchms) (10.3.0)
# Requirement already satisfied: pubchempy in /usr/local/lib/python3.10/dist-packages (from matchms) (1.0.4)
# Requirement already satisfied: pyteomics<5.0,>=4.6 in /usr/local/lib/python3.10/dist-packages (from matchms) (4.7.2)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from matchms) (6.0.1)
# Requirement already satisfied: rdkit<2024.0.0,>=2023.3.2 in /usr/local/lib/python3.10/dist-packages (from matchms) (2023.9.6)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from matchms) (2.31.0)
# Requirement already satisfied: scipy<1.11 in /usr/local/lib/python3.10/dist-packages (from matchms) (1.10.1)
# Requirement already satisfied: sparsestack<0.5.0,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from matchms) (0.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from matchms) (4.66.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated<2.0.0,>=1.2.14->matchms) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->matchms) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->matchms) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->matchms) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->matchms) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->matchms) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->matchms) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->matchms) (2.8.2)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba<0.58.0,>=0.57.1->matchms) (0.40.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.0.3->matchms) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.0.3->matchms) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->matchms) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->matchms) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->matchms) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->matchms) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.7.2->matchms) (1.16.0)

# %%
import matchms as mt

# %%
from matchms.importing import load_from_mgf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/'

# %%
import os

file_mgf = os.path.join(path,
                        "GNPS-NIH-NATURALPRODUCTSLIBRARY.mgf")

# %%
spectrums = list(load_from_mgf(file_mgf))

# %%
inchikeys = [s.get("inchikey") for s in spectrums]
found_inchikeys = np.sum([1 for x in inchikeys if x is not None])
print(f"Found {int(found_inchikeys)} inchikeys in metadata")
# Out:
# Found 0 inchikeys in metadata

# %%
numbers_of_peaks = [len(s.peaks.mz) for s in spectrums]
plt.figure(figsize=(10,3), dpi=150)
plt.hist(numbers_of_peaks, 20, edgecolor="white")
plt.title("Peaks per spectrum (before filtering)")
plt.xlabel("Number of peaks in spectrum")
plt.ylabel("Number of spectra")
plt.show()

# %%
import matchms.filtering as ms_filters

def metadata_processing(spectrum):
    spectrum = ms_filters.default_filters(spectrum)
    spectrum = ms_filters.repair_inchi_inchikey_smiles(spectrum)
    spectrum = ms_filters.derive_inchi_from_smiles(spectrum)
    spectrum = ms_filters.derive_smiles_from_inchi(spectrum)
    spectrum = ms_filters.derive_inchikey_from_inchi(spectrum)
    spectrum = ms_filters.harmonize_undefined_smiles(spectrum)
    spectrum = ms_filters.harmonize_undefined_inchi(spectrum)
    spectrum = ms_filters.harmonize_undefined_inchikey(spectrum)
    spectrum = ms_filters.add_precursor_mz(spectrum)
    return spectrum

# %%
def peak_processing(spectrum):
    spectrum = ms_filters.default_filters(spectrum)
    spectrum = ms_filters.normalize_intensities(spectrum)
    spectrum = ms_filters.select_by_intensity(spectrum, intensity_from=0.01)
    spectrum = ms_filters.select_by_mz(spectrum, mz_from=10, mz_to=1000)
    return spectrum

# %%
spectrums = [metadata_processing(s) for s in spectrums]
spectrums = [peak_processing(s) for s in spectrums]

# %%
numbers_of_peaks = [len(s.peaks.mz) for s in spectrums]
plt.figure(figsize=(10,3), dpi=150)
plt.hist(numbers_of_peaks, 20, edgecolor="white")
plt.title("Peaks per spectrum (before filtering)")
plt.xlabel("Number of peaks in spectrum")
plt.ylabel("Number of spectra")
plt.show()

# %%
inchikeys = [s.get("inchikey") for s in spectrums]
inchikeys[:10]
# Out:
# ['XTJNPXYDTGJZSA-PKOBYXMFSA-N',
#  'VOYWJNWCKFCMPN-FHERZECASA-N',
#  'IRZVHDLBAYNPCT-UHFFFAOYSA-N',
#  'OPWCHZIQXUKNMP-RGEXLXHISA-N',
#  'GTBYYVAKXYVRHX-BVSLBCMMSA-N',
#  'UVZWLAGDMMCHPD-UHFFFAOYSA-N',
#  'XKWILXCQJFNUJH-DEOSSOPVSA-N',
#  'JDZNIWUNOASRIK-UHFFFAOYSA-N',
#  'RCAVVTTVAJETSK-VXKWHMMOSA-N',
#  'KQAZJQXFNDOORW-CABCVRRESA-N']

# %%
len(inchikeys)
# Out:
# 1267

# %%
from matchms import calculate_scores
from matchms.similarity import CosineGreedy
similarity_measure = CosineGreedy(tolerance=0.005)
